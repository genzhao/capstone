# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import KFold
from keras.applications import VGG16
import keras

# %%
zap = pd.read_csv('./zap.csv')

# %%
zap = zap.drop_duplicates(subset=['shoe_hash'])

# %%
zap.shape
# Out:
# (26507, 10)

# %%
zap
# Out:
#                  brand_name                                shoe_name  \
# 0                      Nike                             Flex RN 2017
# 1                      Nike                             Flex RN 2017
# 2                 Nike Kids                  Vapor Varsity Football
# 3                      Nike                      Air Zoom Pegasus 34
# 4                      Nike                      Air Zoom Pegasus 34
# 5                        DC                              Heathrow SE
# 6                   DC Kids                              Trase Slip
# 7                   DC Kids                              Rebound UL
# 8                   DC Kids                             Trase TX SE
# 9                      Nike                      Air Zoom Pegasus 34
# 10                     Nike                      Air Zoom Pegasus 34
# 11                       DC                    Spartan High WC TX SE
# 12                       DC                                    Anvil
# 13                       DC                                 Anvil TX
# 14             Steve Madden                                   Breeze
# 15            Converse Kids       Chuck Taylor All Star Seasonal Hi
# 16              New Balance                                    996v3
# 17                Nike Kids                         Zoom Pegasus 34
# 18             Steve Madden                                   Breeze
# 19            Converse Kids        Chuck Taylor All Star Madison Ox
# 20                Nike Golf                               Explorer 2
# 21     adidas Skateboarding                    Adi-Ease Premiere ADV
# 22                       DC                               Wes Kremer
# 23                  Lacoste                  Explorateur Sport 317 4
# 24                  Lacoste              Explorateur Sport Mid 317 4
# 25            Converse Kids      Chuck Taylor All Star Sport Zip Hi
# 26            Converse Kids  Chuck Taylor All Star Double Tongue Ox
# 27                     Nike                 Alpha Menace Varsity Mid
# 28                  Saucony                            Liteform Feel
# 29              New Balance                      Fresh Foam Vongo v2
# ...                     ...                                      ...
# 28161                  Fila                               Posterizer
# 28162                  Fila                         Memory Workshift
# 28163                  Fila                                  Quadrix
# 28164                 ASICS                             GEL-Sonoma 3
# 28165                  Fila                                  Sweeper
# 28166          Steve Madden                                   Joshua
# 28167               Lacoste                            L.12.12 117 3
# 28168          Steve Madden                                   Kelvin
# 28169              Columbia                             Megavent Fly
# 28170          Steve Madden                                   Londyn
# 28171          Steve Madden                                    Jaeda
# 28172          Steve Madden                                   Kelvin
# 28173          Steve Madden                                   Joshua
# 28174          Steve Madden                                    Jaeda
# 28175             Puma Kids               Basketx Meek Bike Life Jr
# 28176          Steve Madden                                   Patton
# 28177          Steve Madden                                   Kelvin
# 28178                  Reef                              Deck Hand 2
# 28179               Lacoste                  Explorateur Sport 117 1
# 28180                adidas                            Response LT W
# 28181                  Fila                                 Keysport
# 28182            ASICS Kids                     Gel-Noosa Tri 10 GS
# 28184                adidas                   Mana Bounce 2 - Aramis
# 28185               Superga                        2750 Polywoolfanw
# 28186                  Ryka                                     Neve
# 28187                adidas                          Crazy Team 2017
# 28188     Under Armour Kids                         UA BPS Assert V
# 28189                adidas                   Mana Bounce 2 - Aramis
# 28190                  Fila               Head Of The Pack Energized
# 28191                Mizuno                         Wave Creation 18
#
#                                            colorway  colorcode  \
# 0      Black/Metallic Hematite/Anthracite/Dark Grey     684832
# 1               Gym Blue/Black/Star Blue/Photo Blue     684828
# 2                  University Red/White/Black/White     338019
# 3                  Hot Punch/Thunder Blue/Siren Red     684520
# 4           Binary Blue/White/Glacier Grey/Cerulean     684517
# 5                                            Animal       1163
# 6                                         Raspberry        864
# 7                                 Black/White/Multi     129593
# 8                                       Navy/Yellow        515
# 9               Blue Jay/Light Armory Blue/Obsidian     684046
# 10           Ice Blue/Blue Fox/Bright Crimson/White     689845
# 11                                 Grey Resin Rinse     211885
# 12                                         Grey Ash     309781
# 13                                Black/Brown/White      61444
# 14                                            Black          3
# 15                                         Burgundy          7
# 16                            Pigment/Light Cyclone     700978
# 17                     White/Black/Volt/Ghost Green     672227
# 18                                             Grey        401
# 19                            White/Hot Punch/Black     696594
# 20                    Blue Jay/White/University Red     688857
# 21                                Black/White/Gum 2     326552
# 22                                 Black/Blue/White      19729
# 23                                 Dark Khaki/Black      30663
# 24                                       Grey/Black        408
# 25                        White/Sun Blush/Hot Punch     696592
# 26                    Pure Platinum/White/Hot Punch     337502
# 27              University Red/White/Team Red/White     673096
# 28                                            Black          3
# 29                   Black/Energy Lime/Vivid Cobalt     700242
# ...                                             ...        ...
# 28161                   Black/Black/Metallic Silver      11683
# 28162                             Black/Black/Black      24150
# 28163                    Black/Dark Silver/Fila Red     439913
# 28164                Thunder Blue/Black/Green Gecko     658870
# 28165                   Black/Black/Metallic Silver      11683
# 28166                                         Black          3
# 28167                                   White/Green       2537
# 28168                                  Taupe Velvet      44995
# 28169                               White/Deep Wave     715251
# 28170                                         Taupe         11
# 28171                                          Grey        401
# 28172                                  Blush Velvet      16465
# 28173                                         Olive        529
# 28174                                         Blush       5249
# 28175                                         Black          3
# 28176                                    Dusty Pink      24793
# 28177                                   Navy Velvet       9429
# 28178                                         Olive        529
# 28179                                         White         14
# 28180                                  White/Silver        755
# 28181                             White/White/White       5078
# 28182                    Blue/Lighting/Flash Yellow     525829
# 28184           Mystery Blue/Clear Aqua/Glow Orange     661805
# 28185                                   Black Multi         80
# 28186                  Grape Juice/Snozzberry/White     722190
# 28187    Footwear White/MGH Solid Grey/Mystery Blue     659727
# 28188                   High-Vis Yellow/White/Black     491728
# 28189          Ice Purple/Footwear White/Trace Grey     661806
# 28190   Electric Purple/Pink Gloxinia/Safety Yellow     581179
# 28191                    Steel Gray/Skydiver/Silver     631755
#
#                                         lateralfrontleft  \
# 0      http://www.zappos.com/images/z/3/9/3/9/7/0/393...
# 1      http://www.zappos.com/images/z/3/9/3/9/7/0/393...
# 2      http://www.zappos.com/images/z/3/8/8/3/1/2/388...
# 3      http://www.zappos.com/images/z/3/9/3/7/2/0/393...
# 4      http://www.zappos.com/images/z/3/9/3/7/1/9/393...
# 5      http://www.zappos.com/images/z/4/0/0/3/6/7/400...
# 6      http://www.zappos.com/images/z/4/0/2/0/0/6/402...
# 7      http://www.zappos.com/images/z/4/0/2/0/0/0/402...
# 8      http://www.zappos.com/images/z/4/0/1/9/4/4/401...
# 9      http://www.zappos.com/images/z/3/9/3/4/4/3/393...
# 10     http://www.zappos.com/images/z/3/9/6/7/0/7/396...
# 11     http://www.zappos.com/images/z/4/0/1/2/1/8/401...
# 12     http://www.zappos.com/images/z/4/0/0/1/9/1/400...
# 13     http://www.zappos.com/images/z/4/0/0/1/9/2/400...
# 14     http://www.zappos.com/images/z/4/1/1/9/3/3/411...
# 15     http://www.zappos.com/images/z/4/0/1/2/5/8/401...
# 16     http://www.zappos.com/images/z/4/0/3/1/0/3/403...
# 17     http://www.zappos.com/images/z/4/0/0/2/4/7/400...
# 18     http://www.zappos.com/images/z/4/1/1/9/3/4/411...
# 19     http://www.zappos.com/images/z/4/0/0/6/3/7/400...
# 20     http://www.zappos.com/images/z/3/9/6/0/9/8/396...
# 21     http://www.zappos.com/images/z/3/8/0/2/0/8/380...
# 22     http://www.zappos.com/images/z/4/0/0/1/8/3/400...
# 23     http://www.zappos.com/images/z/4/1/0/4/9/5/410...
# 24     http://www.zappos.com/images/z/4/1/0/4/9/5/410...
# 25     http://www.zappos.com/images/z/4/0/0/6/3/7/400...
# 26     http://www.zappos.com/images/z/4/0/0/6/3/7/400...
# 27     http://www.zappos.com/images/z/3/8/8/4/6/2/388...
# 28     http://www.zappos.com/images/z/4/0/1/4/3/7/401...
# 29     http://www.zappos.com/images/z/4/0/2/7/0/0/402...
# ...                                                  ...
# 28161  http://www.zappos.com/images/z/3/3/9/2/5/8/339...
# 28162  http://www.zappos.com/images/z/2/3/3/6/8/5/233...
# 28163  http://www.zappos.com/images/z/3/3/9/2/8/2/339...
# 28164  http://www.zappos.com/images/z/3/7/7/6/3/1/377...
# 28165  http://www.zappos.com/images/z/3/3/9/2/5/7/339...
# 28166  http://www.zappos.com/images/z/4/0/9/5/7/2/409...
# 28167  http://www.zappos.com/images/z/3/8/9/5/1/5/389...
# 28168  http://www.zappos.com/images/z/4/0/9/5/7/2/409...
# 28169  http://www.zappos.com/images/z/4/1/2/7/9/6/412...
# 28170  http://www.zappos.com/images/z/4/0/9/5/7/1/409...
# 28171  http://www.zappos.com/images/z/4/0/9/5/7/1/409...
# 28172  http://www.zappos.com/images/z/4/0/9/5/7/2/409...
# 28173  http://www.zappos.com/images/z/4/0/9/5/7/2/409...
# 28174  http://www.zappos.com/images/z/4/0/9/5/7/1/409...
# 28175  http://www.zappos.com/images/z/4/1/8/0/9/1/418...
# 28176  http://www.zappos.com/images/z/4/0/9/5/7/1/409...
# 28177  http://www.zappos.com/images/z/4/0/9/5/7/2/409...
# 28178  http://www.zappos.com/images/z/2/4/3/0/9/7/243...
# 28179  http://www.zappos.com/images/z/4/1/6/6/6/4/416...
# 28180  http://www.zappos.com/images/z/4/1/7/0/1/8/417...
# 28181  http://www.zappos.com/images/z/4/1/4/1/5/4/414...
# 28182  http://www.zappos.com/images/z/2/9/6/6/0/8/296...
# 28184  http://www.zappos.com/images/z/3/7/9/1/0/2/379...
# 28185  http://www.zappos.com/images/z/3/6/6/6/4/5/366...
# 28186  http://www.zappos.com/images/z/4/1/6/8/0/5/416...
# 28187  http://www.zappos.com/images/z/3/7/7/9/5/6/377...
# 28188  http://www.zappos.com/images/z/3/1/7/8/3/1/317...
# 28189  http://www.zappos.com/images/z/3/7/9/1/0/1/379...
# 28190  http://www.zappos.com/images/z/3/2/9/6/7/9/329...
# 28191  http://www.zappos.com/images/z/3/5/9/9/2/8/359...
#
#                                                 heelview  \
# 0      http://www.zappos.com/images/z/3/9/3/9/7/0/393...
# 1      http://www.zappos.com/images/z/3/9/3/9/7/0/393...
# 2      http://www.zappos.com/images/z/3/8/8/3/1/2/388...
# 3      http://www.zappos.com/images/z/3/9/3/7/2/0/393...
# 4      http://www.zappos.com/images/z/3/9/3/7/1/9/393...
# 5      http://www.zappos.com/images/z/4/0/0/3/6/7/400...
# 6      http://www.zappos.com/images/z/4/0/2/0/0/6/402...
# 7      http://www.zappos.com/images/z/4/0/2/0/0/0/402...
# 8      http://www.zappos.com/images/z/4/0/1/9/4/4/401...
# 9      http://www.zappos.com/images/z/3/9/3/4/4/3/393...
# 10     http://www.zappos.com/images/z/3/9/6/7/0/7/396...
# 11     http://www.zappos.com/images/z/4/0/1/2/1/8/401...
# 12     http://www.zappos.com/images/z/4/0/0/1/9/1/400...
# 13     http://www.zappos.com/images/z/4/0/0/1/9/2/400...
# 14     http://www.zappos.com/images/z/4/1/1/9/3/3/411...
# 15     http://www.zappos.com/images/z/4/0/1/2/5/8/401...
# 16     http://www.zappos.com/images/z/4/0/3/1/0/3/403...
# 17     http://www.zappos.com/images/z/4/0/0/2/4/7/400...
# 18     http://www.zappos.com/images/z/4/1/1/9/3/4/411...
# 19     http://www.zappos.com/images/z/4/0/0/6/3/7/400...
# 20     http://www.zappos.com/images/z/3/9/6/0/9/8/396...
# 21     http://www.zappos.com/images/z/3/8/0/2/0/8/380...
# 22     http://www.zappos.com/images/z/4/0/0/1/8/3/400...
# 23     http://www.zappos.com/images/z/4/1/0/4/9/5/410...
# 24     http://www.zappos.com/images/z/4/1/0/4/9/5/410...
# 25     http://www.zappos.com/images/z/4/0/0/6/3/7/400...
# 26     http://www.zappos.com/images/z/4/0/0/6/3/7/400...
# 27     http://www.zappos.com/images/z/3/8/8/4/6/2/388...
# 28     http://www.zappos.com/images/z/4/0/1/4/3/7/401...
# 29     http://www.zappos.com/images/z/4/0/2/7/0/0/402...
# ...                                                  ...
# 28161  http://www.zappos.com/images/z/3/3/9/2/5/8/339...
# 28162  http://www.zappos.com/images/z/2/3/3/6/8/5/233...
# 28163  http://www.zappos.com/images/z/3/3/9/2/8/2/339...
# 28164  http://www.zappos.com/images/z/3/7/7/6/3/1/377...
# 28165  http://www.zappos.com/images/z/3/3/9/2/5/7/339...
# 28166  http://www.zappos.com/images/z/4/0/9/5/7/2/409...
# 28167  http://www.zappos.com/images/z/3/8/9/5/1/5/389...
# 28168  http://www.zappos.com/images/z/4/0/9/5/7/2/409...
# 28169  http://www.zappos.com/images/z/4/1/2/7/9/6/412...
# 28170  http://www.zappos.com/images/z/4/0/9/5/7/1/409...
# 28171  http://www.zappos.com/images/z/4/0/9/5/7/1/409...
# 28172  http://www.zappos.com/images/z/4/0/9/5/7/2/409...
# 28173  http://www.zappos.com/images/z/4/0/9/5/7/2/409...
# 28174  http://www.zappos.com/images/z/4/0/9/5/7/1/409...
# 28175  http://www.zappos.com/images/z/4/1/8/0/9/1/418...
# 28176  http://www.zappos.com/images/z/4/0/9/5/7/1/409...
# 28177  http://www.zappos.com/images/z/4/0/9/5/7/2/409...
# 28178  http://www.zappos.com/images/z/2/4/3/0/9/7/243...
# 28179  http://www.zappos.com/images/z/4/1/6/6/6/4/416...
# 28180  http://www.zappos.com/images/z/4/1/7/0/1/8/417...
# 28181  http://www.zappos.com/images/z/4/1/4/1/5/4/414...
# 28182  http://www.zappos.com/images/z/2/9/6/6/0/8/296...
# 28184  http://www.zappos.com/images/z/3/7/9/1/0/2/379...
# 28185  http://www.zappos.com/images/z/3/6/6/6/4/5/366...
# 28186  http://www.zappos.com/images/z/4/1/6/8/0/5/416...
# 28187  http://www.zappos.com/images/z/3/7/7/9/5/6/377...
# 28188  http://www.zappos.com/images/z/3/1/7/8/3/1/317...
# 28189  http://www.zappos.com/images/z/3/7/9/1/0/1/379...
# 28190  http://www.zappos.com/images/z/3/2/9/6/7/9/329...
# 28191  http://www.zappos.com/images/z/3/5/9/9/2/8/359...
#
#                                                  toeview  \
# 0      http://www.zappos.com/images/z/3/9/3/9/7/0/393...
# 1      http://www.zappos.com/images/z/3/9/3/9/7/0/393...
# 2      http://www.zappos.com/images/z/3/8/8/3/1/2/388...
# 3      http://www.zappos.com/images/z/3/9/3/7/2/0/393...
# 4      http://www.zappos.com/images/z/3/9/3/7/1/9/393...
# 5      http://www.zappos.com/images/z/4/0/0/3/6/7/400...
# 6      http://www.zappos.com/images/z/4/0/2/0/0/6/402...
# 7      http://www.zappos.com/images/z/4/0/2/0/0/0/402...
# 8      http://www.zappos.com/images/z/4/0/1/9/4/4/401...
# 9      http://www.zappos.com/images/z/3/9/3/4/4/3/393...
# 10     http://www.zappos.com/images/z/3/9/6/7/0/7/396...
# 11     http://www.zappos.com/images/z/4/0/1/2/1/8/401...
# 12     http://www.zappos.com/images/z/4/0/0/1/9/1/400...
# 13     http://www.zappos.com/images/z/4/0/0/1/9/2/400...
# 14     http://www.zappos.com/images/z/4/1/1/9/3/3/411...
# 15     http://www.zappos.com/images/z/4/0/1/2/5/8/401...
# 16     http://www.zappos.com/images/z/4/0/3/1/0/3/403...
# 17     http://www.zappos.com/images/z/4/0/0/2/4/7/400...
# 18     http://www.zappos.com/images/z/4/1/1/9/3/4/411...
# 19     http://www.zappos.com/images/z/4/0/0/6/3/7/400...
# 20     http://www.zappos.com/images/z/3/9/6/0/9/8/396...
# 21     http://www.zappos.com/images/z/3/8/0/2/0/8/380...
# 22     http://www.zappos.com/images/z/4/0/0/1/8/3/400...
# 23     http://www.zappos.com/images/z/4/1/0/4/9/5/410...
# 24     http://www.zappos.com/images/z/4/1/0/4/9/5/410...
# 25     http://www.zappos.com/images/z/4/0/0/6/3/7/400...
# 26     http://www.zappos.com/images/z/4/0/0/6/3/7/400...
# 27     http://www.zappos.com/images/z/3/8/8/4/6/2/388...
# 28     http://www.zappos.com/images/z/4/0/1/4/3/7/401...
# 29     http://www.zappos.com/images/z/4/0/2/7/0/0/402...
# ...                                                  ...
# 28161  http://www.zappos.com/images/z/3/3/9/2/5/8/339...
# 28162  http://www.zappos.com/images/z/2/3/3/6/8/5/233...
# 28163  http://www.zappos.com/images/z/3/3/9/2/8/2/339...
# 28164  http://www.zappos.com/images/z/3/7/7/6/3/1/377...
# 28165  http://www.zappos.com/images/z/3/3/9/2/5/7/339...
# 28166  http://www.zappos.com/images/z/4/0/9/5/7/2/409...
# 28167  http://www.zappos.com/images/z/3/8/9/5/1/5/389...
# 28168  http://www.zappos.com/images/z/4/0/9/5/7/2/409...
# 28169  http://www.zappos.com/images/z/4/1/2/7/9/6/412...
# 28170  http://www.zappos.com/images/z/4/0/9/5/7/1/409...
# 28171  http://www.zappos.com/images/z/4/0/9/5/7/1/409...
# 28172  http://www.zappos.com/images/z/4/0/9/5/7/2/409...
# 28173  http://www.zappos.com/images/z/4/0/9/5/7/2/409...
# 28174  http://www.zappos.com/images/z/4/0/9/5/7/1/409...
# 28175  http://www.zappos.com/images/z/4/1/8/0/9/1/418...
# 28176  http://www.zappos.com/images/z/4/0/9/5/7/1/409...
# 28177  http://www.zappos.com/images/z/4/0/9/5/7/2/409...
# 28178  http://www.zappos.com/images/z/2/4/3/0/9/7/243...
# 28179  http://www.zappos.com/images/z/4/1/6/6/6/4/416...
# 28180  http://www.zappos.com/images/z/4/1/7/0/1/8/417...
# 28181  http://www.zappos.com/images/z/4/1/4/1/5/4/414...
# 28182  http://www.zappos.com/images/z/2/9/6/6/0/8/296...
# 28184  http://www.zappos.com/images/z/3/7/9/1/0/2/379...
# 28185  http://www.zappos.com/images/z/3/6/6/6/4/5/366...
# 28186  http://www.zappos.com/images/z/4/1/6/8/0/5/416...
# 28187  http://www.zappos.com/images/z/3/7/7/9/5/6/377...
# 28188  http://www.zappos.com/images/z/3/1/7/8/3/1/317...
# 28189  http://www.zappos.com/images/z/3/7/9/1/0/1/379...
# 28190  http://www.zappos.com/images/z/3/2/9/6/7/9/329...
# 28191  http://www.zappos.com/images/z/3/5/9/9/2/8/359...
#
#                                         medialfrontright  \
# 0      http://www.zappos.com/images/z/3/9/3/9/7/0/393...
# 1      http://www.zappos.com/images/z/3/9/3/9/7/0/393...
# 2      http://www.zappos.com/images/z/3/8/8/3/1/2/388...
# 3      http://www.zappos.com/images/z/3/9/3/7/2/0/393...
# 4      http://www.zappos.com/images/z/3/9/3/7/1/9/393...
# 5      http://www.zappos.com/images/z/4/0/0/3/6/7/400...
# 6      http://www.zappos.com/images/z/4/0/2/0/0/6/402...
# 7      http://www.zappos.com/images/z/4/0/2/0/0/0/402...
# 8      http://www.zappos.com/images/z/4/0/1/9/4/4/401...
# 9      http://www.zappos.com/images/z/3/9/3/4/4/3/393...
# 10     http://www.zappos.com/images/z/3/9/6/7/0/7/396...
# 11     http://www.zappos.com/images/z/4/0/1/2/1/8/401...
# 12     http://www.zappos.com/images/z/4/0/0/1/9/1/400...
# 13     http://www.zappos.com/images/z/4/0/0/1/9/2/400...
# 14     http://www.zappos.com/images/z/4/1/1/9/3/3/411...
# 15     http://www.zappos.com/images/z/4/0/1/2/5/8/401...
# 16     http://www.zappos.com/images/z/4/0/3/1/0/3/403...
# 17     http://www.zappos.com/images/z/4/0/0/2/4/7/400...
# 18     http://www.zappos.com/images/z/4/1/1/9/3/4/411...
# 19     http://www.zappos.com/images/z/4/0/0/6/3/7/400...
# 20     http://www.zappos.com/images/z/3/9/6/0/9/8/396...
# 21     http://www.zappos.com/images/z/3/8/0/2/0/8/380...
# 22     http://www.zappos.com/images/z/4/0/0/1/8/3/400...
# 23     http://www.zappos.com/images/z/4/1/0/4/9/5/410...
# 24     http://www.zappos.com/images/z/4/1/0/4/9/5/410...
# 25     http://www.zappos.com/images/z/4/0/0/6/3/7/400...
# 26     http://www.zappos.com/images/z/4/0/0/6/3/7/400...
# 27     http://www.zappos.com/images/z/3/8/8/4/6/2/388...
# 28     http://www.zappos.com/images/z/4/0/1/4/3/7/401...
# 29     http://www.zappos.com/images/z/4/0/2/7/0/0/402...
# ...                                                  ...
# 28161  http://www.zappos.com/images/z/3/3/9/2/5/8/339...
# 28162  http://www.zappos.com/images/z/2/3/3/6/8/5/233...
# 28163  http://www.zappos.com/images/z/3/3/9/2/8/2/339...
# 28164  http://www.zappos.com/images/z/3/7/7/6/3/1/377...
# 28165  http://www.zappos.com/images/z/3/3/9/2/5/7/339...
# 28166  http://www.zappos.com/images/z/4/0/9/5/7/2/409...
# 28167  http://www.zappos.com/images/z/3/8/9/5/1/5/389...
# 28168  http://www.zappos.com/images/z/4/0/9/5/7/2/409...
# 28169  http://www.zappos.com/images/z/4/1/2/7/9/6/412...
# 28170  http://www.zappos.com/images/z/4/0/9/5/7/1/409...
# 28171  http://www.zappos.com/images/z/4/0/9/5/7/1/409...
# 28172  http://www.zappos.com/images/z/4/0/9/5/7/2/409...
# 28173  http://www.zappos.com/images/z/4/0/9/5/7/2/409...
# 28174  http://www.zappos.com/images/z/4/0/9/5/7/1/409...
# 28175  http://www.zappos.com/images/z/4/1/8/0/9/1/418...
# 28176  http://www.zappos.com/images/z/4/0/9/5/7/1/409...
# 28177  http://www.zappos.com/images/z/4/0/9/5/7/2/409...
# 28178  http://www.zappos.com/images/z/2/4/3/0/9/7/243...
# 28179  http://www.zappos.com/images/z/4/1/6/6/6/4/416...
# 28180  http://www.zappos.com/images/z/4/1/7/0/1/8/417...
# 28181  http://www.zappos.com/images/z/4/1/4/1/5/4/414...
# 28182  http://www.zappos.com/images/z/2/9/6/6/0/8/296...
# 28184  http://www.zappos.com/images/z/3/7/9/1/0/2/379...
# 28185  http://www.zappos.com/images/z/3/6/6/6/4/5/366...
# 28186  http://www.zappos.com/images/z/4/1/6/8/0/5/416...
# 28187  http://www.zappos.com/images/z/3/7/7/9/5/6/377...
# 28188  http://www.zappos.com/images/z/3/1/7/8/3/1/317...
# 28189  http://www.zappos.com/images/z/3/7/9/1/0/1/379...
# 28190  http://www.zappos.com/images/z/3/2/9/6/7/9/329...
# 28191  http://www.zappos.com/images/z/3/5/9/9/2/8/359...
#
#                                                  topview       shoe_hash
# 0      http://www.zappos.com/images/z/3/9/3/9/7/0/393...      0_0_684832
# 1      http://www.zappos.com/images/z/3/9/3/9/7/0/393...      0_0_684828
# 2      http://www.zappos.com/images/z/3/8/8/3/1/2/388...      1_1_338019
# 3      http://www.zappos.com/images/z/3/9/3/7/2/0/393...      0_2_684520
# 4      http://www.zappos.com/images/z/3/9/3/7/1/9/393...      0_2_684517
# 5      http://www.zappos.com/images/z/4/0/0/3/6/7/400...        2_3_1163
# 6      http://www.zappos.com/images/z/4/0/2/0/0/6/402...         3_4_864
# 7      http://www.zappos.com/images/z/4/0/2/0/0/0/402...      3_5_129593
# 8      http://www.zappos.com/images/z/4/0/1/9/4/4/401...         3_6_515
# 9      http://www.zappos.com/images/z/3/9/3/4/4/3/393...      0_2_684046
# 10     http://www.zappos.com/images/z/3/9/6/7/0/7/396...      0_2_689845
# 11     http://www.zappos.com/images/z/4/0/1/2/1/8/401...      2_7_211885
# 12     http://www.zappos.com/images/z/4/0/0/1/9/1/400...      2_8_309781
# 13     http://www.zappos.com/images/z/4/0/0/1/9/2/400...       2_9_61444
# 14     http://www.zappos.com/images/z/4/1/1/9/3/3/411...          4_10_3
# 15     http://www.zappos.com/images/z/4/0/1/2/5/8/401...          5_11_7
# 16     http://www.zappos.com/images/z/4/0/3/1/0/3/403...     6_12_700978
# 17     http://www.zappos.com/images/z/4/0/0/2/4/7/400...     1_13_672227
# 18     http://www.zappos.com/images/z/4/1/1/9/3/4/411...        4_10_401
# 19     http://www.zappos.com/images/z/4/0/0/6/3/7/400...     5_14_696594
# 20     http://www.zappos.com/images/z/3/9/6/0/9/8/396...     7_15_688857
# 21     http://www.zappos.com/images/z/3/8/0/2/0/8/380...     8_16_326552
# 22     http://www.zappos.com/images/z/4/0/0/1/8/3/400...      2_17_19729
# 23     http://www.zappos.com/images/z/4/1/0/4/9/5/410...      9_18_30663
# 24     http://www.zappos.com/images/z/4/1/0/4/9/5/410...        9_19_408
# 25     http://www.zappos.com/images/z/4/0/0/6/3/7/400...     5_20_696592
# 26     http://www.zappos.com/images/z/4/0/0/6/3/7/400...     5_21_337502
# 27     http://www.zappos.com/images/z/3/8/8/4/6/2/388...     0_22_673096
# 28     http://www.zappos.com/images/z/4/0/1/4/3/7/401...         10_23_3
# 29     http://www.zappos.com/images/z/4/0/2/7/0/0/402...     6_24_700242
# ...                                                  ...             ...
# 28161  http://www.zappos.com/images/z/3/3/9/2/5/8/339...   96_8875_11683
# 28162  http://www.zappos.com/images/z/2/3/3/6/8/5/233...   96_4025_24150
# 28163  http://www.zappos.com/images/z/3/3/9/2/8/2/339...  96_5974_439913
# 28164  http://www.zappos.com/images/z/3/7/7/6/3/1/377...   24_200_658870
# 28165  http://www.zappos.com/images/z/3/3/9/2/5/7/339...   96_3953_11683
# 28166  http://www.zappos.com/images/z/4/0/9/5/7/2/409...        4_8878_3
# 28167  http://www.zappos.com/images/z/3/8/9/5/1/5/389...     9_8879_2537
# 28168  http://www.zappos.com/images/z/4/0/9/5/7/2/409...    4_8880_44995
# 28169  http://www.zappos.com/images/z/4/1/2/7/9/6/412...  48_6442_715251
# 28170  http://www.zappos.com/images/z/4/0/9/5/7/1/409...       4_8881_11
# 28171  http://www.zappos.com/images/z/4/0/9/5/7/1/409...      4_8882_401
# 28172  http://www.zappos.com/images/z/4/0/9/5/7/2/409...    4_8880_16465
# 28173  http://www.zappos.com/images/z/4/0/9/5/7/2/409...      4_8878_529
# 28174  http://www.zappos.com/images/z/4/0/9/5/7/1/409...     4_8882_5249
# 28175  http://www.zappos.com/images/z/4/1/8/0/9/1/418...       31_8883_3
# 28176  http://www.zappos.com/images/z/4/0/9/5/7/1/409...    4_8884_24793
# 28177  http://www.zappos.com/images/z/4/0/9/5/7/2/409...     4_8880_9429
# 28178  http://www.zappos.com/images/z/2/4/3/0/9/7/243...     67_2613_529
# 28179  http://www.zappos.com/images/z/4/1/6/6/6/4/416...       9_8565_14
# 28180  http://www.zappos.com/images/z/4/1/7/0/1/8/417...     47_8885_755
# 28181  http://www.zappos.com/images/z/4/1/4/1/5/4/414...    96_3962_5078
# 28182  http://www.zappos.com/images/z/2/9/6/6/0/8/296...  33_8886_525829
# 28184  http://www.zappos.com/images/z/3/7/9/1/0/2/379...   47_247_661805
# 28185  http://www.zappos.com/images/z/3/6/6/6/4/5/366...      61_8887_80
# 28186  http://www.zappos.com/images/z/4/1/6/8/0/5/416...  54_3505_722190
# 28187  http://www.zappos.com/images/z/3/7/7/9/5/6/377...  47_3124_659727
# 28188  http://www.zappos.com/images/z/3/1/7/8/3/1/317...  21_8888_491728
# 28189  http://www.zappos.com/images/z/3/7/9/1/0/1/379...   47_247_661806
# 28190  http://www.zappos.com/images/z/3/2/9/6/7/9/329...  96_8889_581179
# 28191  http://www.zappos.com/images/z/3/5/9/9/2/8/359...   60_505_631755
#
# [26507 rows x 10 columns]

# %%
nobrand = zap.drop('brand_name',axis = 1)

# %%
X = nobrand.values
y = zap.brand_name.values
skf = StratifiedKFold(n_splits=3)

# %%
print X.shape
y.shape
# Out:
# (26507, 9)
# (26507,)

# %%
print skf
# Out:
# StratifiedKFold(n_splits=3, random_state=None, shuffle=False)

# %%
for train_index, test_index in skf.split(X, y):
    print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
# Out:
# ('TRAIN:', array([ 2313,  2420,  2426, ..., 26504, 26505, 26506]), 'TEST:', array([    0,     1,     2, ..., 17338, 17347, 17375]))
# ('TRAIN:', array([    0,     1,     2, ..., 26504, 26505, 26506]), 'TEST:', array([ 2313,  2420,  2426, ..., 23815, 24315, 25205]))
# ('TRAIN:', array([    0,     1,     2, ..., 23815, 24315, 25205]), 'TEST:', array([ 4604,  4606,  4609, ..., 26504, 26505, 26506]))

# %%
vgg = VGG16()

# %%
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
from keras.layers import Input, Flatten, Dense
from keras.models import Model
import numpy as np

#Get back the convolutional part of a VGG network trained on ImageNet
model_vgg16_conv = VGG16(weights='imagenet', include_top=False)
model_vgg16_conv.summary()

#Create your own input format (here 3x200x200)
input = Input(shape=(224,224,3),name = 'image_input')

#Use the generated model 
output_vgg16_conv = model_vgg16_conv(input)

#Add the fully-connected layers 
x = Flatten(name='flatten')(output_vgg16_conv)
x = Dense(4096, activation='relu', name='fc1')(x)
x = Dense(4096, activation='relu', name='fc2')(x)
x = Dense(8, activation='softmax', name='predictions')(x)

#Create your own model 
my_model = Model(input=input, output=x)

#In the summary, weights and layers from VGG part will be hidden, but they will be fit during the training
my_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_11 (InputLayer)        (None, None, None, 3)     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, None, None, 256)   295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, None, None, 256)   0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, None, None, 512)   1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, None, None, 512)   0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# image_input (InputLayer)     (None, 224, 224, 3)       0
# _________________________________________________________________
# vgg16 (Model)                multiple                  14714688
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 8)                 32776
# =================================================================
# Total params: 134,293,320
# Trainable params: 134,293,320
# Non-trainable params: 0
# _________________________________________________________________
# /anaconda/envs/dsi/lib/python2.7/site-packages/ipykernel/__main__.py:25: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=Tensor("pr..., inputs=Tensor("im...)`

# %%
features_for_train_data = my_model.predict(X_train)
features_for_test_data = my_model.predict(X_val)
adam = keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
my_model.compile(optimizer=adam,
              loss='mse',
              metrics=['accuracy'])

my_model.fit(features_for_train_data, y_train,
          nb_epoch=80,
          batch_size=32,
          validation_data=(features_for_test_data, y_val))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-a0ae75c71e93> in <module>()
# ----> 1 features_for_train_data = my_model.predict(X_train)
#       2 features_for_test_data = my_model.predict(X_val)
#       3 adam = keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
#       4 my_model.compile(optimizer=adam,
#       5               loss='mse',
#
# /anaconda/envs/dsi/lib/python2.7/site-packages/keras/engine/training.pyc in predict(self, x, batch_size, verbose)
#    1497         x = _standardize_input_data(x, self._feed_input_names,
#    1498                                     self._feed_input_shapes,
# -> 1499                                     check_batch_axis=False)
#    1500         if self.stateful:
#    1501             if x[0].shape[0] > batch_size and x[0].shape[0] % batch_size != 0:
#
# /anaconda/envs/dsi/lib/python2.7/site-packages/keras/engine/training.pyc in _standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     126                                  ' to have ' + str(len(shapes[i])) +
#     127                                  ' dimensions, but got array with shape ' +
# --> 128                                  str(array.shape))
#     129             for j, (dim, ref_dim) in enumerate(zip(array.shape, shapes[i])):
#     130                 if not j and not check_batch_axis:
#
# ValueError: Error when checking : expected input_9 to have 4 dimensions, but got array with shape (17700, 9)

# %%
# Generate a model with all layers (with top)
vgg16 = VGG16(weights=None, include_top=True)

#Add a layer where input is the output of the  second last layer 
x = Dense(8, activation='softmax', name='predictions')(vgg16.layers[-2].output)

#Then create the corresponding model 
my_model = Model(input=vgg16.input, output=x)
my_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 8)                 32776
# =================================================================
# Total params: 134,293,320
# Trainable params: 134,293,320
# Non-trainable params: 0
# _________________________________________________________________
# /anaconda/envs/dsi/lib/python2.7/site-packages/ipykernel/__main__.py:8: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=Tensor("pr..., inputs=Tensor("in...)`

# %%
from keras.models import Sequential
model = Sequential()

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Conv2D
from keras.layers import MaxPooling2D

input_shape = (224, 224, 3)

model = Sequential([
    Conv2D(64, (3, 3), input_shape=input_shape, padding='same',
           activation='relu'),
    Conv2D(64, (3, 3), activation='relu', padding='same'),
    MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),
    Conv2D(128, (3, 3), activation='relu', padding='same'),
    Conv2D(128, (3, 3), activation='relu', padding='same',),
    MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),
    Conv2D(256, (3, 3), activation='relu', padding='same',),
    Conv2D(256, (3, 3), activation='relu', padding='same',),
    Conv2D(256, (3, 3), activation='relu', padding='same',),
    MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),
    Conv2D(512, (3, 3), activation='relu', padding='same',),
    Conv2D(512, (3, 3), activation='relu', padding='same',),
    Conv2D(512, (3, 3), activation='relu', padding='same',),
    MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),
    Conv2D(512, (3, 3), activation='relu', padding='same',),
    Conv2D(512, (3, 3), activation='relu', padding='same',),
    Conv2D(512, (3, 3), activation='relu', padding='same',),
    MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),
    Flatten(),
    Dense(4096, activation='relu'),
    Dense(4096, activation='relu'),
    Dense(1000, activation='softmax')
])

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 224, 224, 64)      1792
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 224, 224, 64)      36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 112, 112, 128)     73856
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 112, 112, 128)     147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 56, 56, 256)       295168
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 56, 56, 256)       590080
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 56, 56, 256)       590080
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 28, 28, 512)       1180160
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 28, 28, 512)       2359808
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 28, 28, 512)       2359808
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 14, 14, 512)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              102764544
# _________________________________________________________________
# dense_2 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dense_3 (Dense)              (None, 1000)              4097000
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

x = #load_array
x = x.reshape((1,) + x.shape)  # this is a Numpy array with shape (1, 3, 150, 150)

# the .flow() command below generates batches of randomly transformed images
# and saves the results to the `preview/` directory
i = 0
for batch in datagen.flow(x, batch_size=1,
                          save_to_dir='preview', save_prefix='cat', save_format='jpeg'):
    i += 1
    if i > 20:
        break  # otherwise the generator would loop indefinitely
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-838c94a4e83c> in <module>()
#       2
#       3
# ----> 4 x = x.reshape((1,) + x.shape)  # this is a Numpy array with shape (1, 3, 150, 150)
#       5
#       6 # the .flow() command below generates batches of randomly transformed images
#
# NameError: name 'x' is not defined

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense

model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(3, 224, 224)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# %%
model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
batch_size = 16

# this is the augmentation configuration we will use for training
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

# this is the augmentation configuration we will use for testing:
# only rescaling
test_datagen = ImageDataGenerator(rescale=1./255)

# this is a generator that will read pictures found in
# subfolers of 'data/train', and indefinitely generate
# batches of augmented image data
train_generator = train_datagen.flow_from_directory(
        'data/train',  # this is the target directory
        target_size=(150, 150),  # all images will be resized to 150x150
        batch_size=batch_size,
        class_mode='binary')  # since we use binary_crossentropy loss, we need binary labels

# this is a similar generator, for validation data
validation_generator = test_datagen.flow_from_directory(
        'data/validation',
        target_size=(150, 150),
        batch_size=batch_size,
        class_mode='binary')
